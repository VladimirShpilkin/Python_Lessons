# %%
#Установка библиотеки sympy для решения уравнений

# !pip install sympy

# %%
#symbols - создание неизвестных переменных
#Eq - создание уравнения
#solve - решение уравнения
from sympy import symbols, Eq, solve

# %%
x = symbols("x")

# %% [markdown]
# Task 1

# %%
equation = Eq((67+33)/25, x/(25-20))
print(int(solve(equation, x)[0]))
# Out:
# 20

# %% [markdown]
# Task 2

# %%
round((4+(5*60)-17+(65/4))**(1/2),3)
# Out:
# 17.414

# %% [markdown]
# Task 3

# %%
round((6.996 + 45*((13/2)**2) + 2 *(18**(1/2))), 3)
# Out:
# 1916.731

# %% [markdown]
# Task 4

# %%
(1267-(20*((5**3)/2)**2))/((8**5)*(36**(1/2)))
# Out:
# -0.3909200032552083

# %% [markdown]
# Task 5

# %%
((((9**(1/2))**3)**2)**2)/(-2**(-3))
# Out:
# -4251528.0
